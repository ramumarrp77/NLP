# %% [markdown]
# # Twitter data
#
# ## Copyright and Licensing
#
# You are free to use or adapt this notebook for any purpose you'd like. However, please respect the [Simplified BSD License](https://github.com/ptwobrussell/Mining-the-Social-Web-2nd-Edition/blob/master/LICENSE.txt) that governs its use.

# %% [markdown]
# # Twitter API Access
#
# Twitter implements OAuth 1.0A as its standard authentication mechanism, and in order to use it to make requests to Twitter's API, you'll need to go to https://dev.twitter.com/apps and create a sample application.
#
# Choose any name for your application, write a description and use `http://google.com` for the website.
#
# Under **Key and Access Tokens**, there are four primary identifiers you'll need to note for an OAuth 1.0A workflow:
# * consumer key,
# * consumer secret,
# * access token, and
# * access token secret (Click on Create Access Token to create those).
#
# Note that you will need an ordinary Twitter account in order to login, create an app, and get these credentials.

# %% [markdown]
# The first time you execute the notebook, add all credentials so that you can save them in the `pkl` file, then you can remove the secret keys from the notebook because they will just be loaded from the `pkl` file.
#
# The `pkl` file contains sensitive information that can be used to take control of your twitter acccount, **do not share it**.

# %%
import pickle
import os

# %%
if not os.path.exists('secret_twitter_credentials.pkl'):
    Twitter={}
    Twitter['Consumer Key'] = '2MhIKFCy1TGU6qpR16cYGcfsx'
    Twitter['Consumer Secret'] = 'YFwi89ZtUqfml69QRCBJQnlpsXT2PJZHcCMNQJHO6xhz25uCN2'
    Twitter['Access Token'] = '801452532577030144-lnPJ4ltWqxa7TKoMbRx2WSeF8OtSi6K'
    Twitter['Access Token Secret'] = 'KGJjj3R5bd4gFBYArboT3B7961ZnJG8EFa8icXUtlWygz'
    with open('secret_twitter_credentials.pkl','wb') as f:
        pickle.dump(Twitter, f)
else:
    Twitter=pickle.load(open('secret_twitter_credentials.pkl','rb'))

# %% [markdown]
# Install the `twitter` package to interface with the Twitter API

# %%
# !pip install twitter
# Out:
# Requirement already satisfied: twitter in c:\users\ram kumar r p\anaconda3\lib\site-packages (1.18.0)

# %% [markdown]
# ## Example 1. Authorizing an application to access Twitter account data

# %%
import twitter

auth = twitter.oauth.OAuth(Twitter['Access Token'],
                           Twitter['Access Token Secret'],
                           Twitter['Consumer Key'],
                           Twitter['Consumer Secret'])

twitter_api = twitter.Twitter(auth=auth)

# Nothing to see by displaying twitter_api except that it's now a
# defined variable

print(twitter_api)
# Out:
# <twitter.api.Twitter object at 0x0000021944CF3438>

# %% [markdown]
# ## Example 2. Retrieving trends

# %% [markdown]
# Twitter identifies locations using the Yahoo! Where On Earth ID.
#
# The Yahoo! Where On Earth ID for the entire world is 1.
# See https://dev.twitter.com/docs/api/1.1/get/trends/place and
# http://developer.yahoo.com/geo/geoplanet/
#
# look at the BOSS placefinder here: https://developer.yahoo.com/boss/placefinder/

# %%
WORLD_WOE_ID = 1
US_WOE_ID = 23424848

# %% [markdown]
# Look for the WOEID for [san-diego](http://woeid.rosselliot.co.nz/lookup/san%20diego%20%20ca)
#
# You can change it to another location.

# %%
LOCAL_WOE_ID=2295424

# Prefix ID with the underscore for query string parameterization.
# Without the underscore, the twitter package appends the ID value
# to the URL itself as a special case keyword argument.

world_trends = twitter_api.trends.place(_id=WORLD_WOE_ID)
us_trends = twitter_api.trends.place(_id=US_WOE_ID)
local_trends = twitter_api.trends.place(_id=LOCAL_WOE_ID)

# %%
world_trends[:2]
# Out:
# [{'trends': [{'name': '京アニ',
#     'url': 'http://twitter.com/search?q=%E4%BA%AC%E3%82%A2%E3%83%8B',
#     'promoted_content': None,
#     'query': '%E4%BA%AC%E3%82%A2%E3%83%8B',
#     'tweet_volume': 1750869},
#    {'name': '#PrayForKyoani',
#     'url': 'http://twitter.com/search?q=%23PrayForKyoani',
#     'promoted_content': None,
#     'query': '%23PrayForKyoani',
#     'tweet_volume': 125724},
#    {'name': '死者25人',
#     'url': 'http://twitter.com/search?q=%E6%AD%BB%E8%80%8525%E4%BA%BA',
#     'promoted_content': None,
#     'query': '%E6%AD%BB%E8%80%8525%E4%BA%BA',
#     'tweet_volume': 90320},
#    {'name': '#TAEYONG_LongFlight',
#     'url': 'http://twitter.com/search?q=%23TAEYONG_LongFlight',
#     'promoted_content': None,
#     'query': '%23TAEYONG_LongFlight',
#     'tweet_volume': 207234},
#    {'name': '#instagramDELETE',
#     'url': 'http://twitter.com/search?q=%23instagramDELETE',
#     'promoted_content': None,
#     'query': '%23instagramDELETE',
#     'tweet_volume': None},
#    {'name': '#TheFinalQuarter',
#     'url': 'http://twitter.com/search?q=%23TheFinalQuarter',
#     'promoted_content': None,
#     'query': '%23TheFinalQuarter',
#     'tweet_volume': None},
#    {'name': 'ニュース',
#     'url': 'http://twitter.com/search?q=%E3%83%8B%E3%83%A5%E3%83%BC%E3%82%B9',
#     'promoted_content': None,
#     'query': '%E3%83%8B%E3%83%A5%E3%83%BC%E3%82%B9',
#     'tweet_volume': 589231},
#    {'name': '#TaekookersGoingToJailParty',
#     'url': 'http://twitter.com/search?q=%23TaekookersGoingToJailParty',
#     'promoted_content': None,
#     'query': '%23TaekookersGoingToJailParty',
#     'tweet_volume': 44464},
#    {'name': 'CLANNAD',
#     'url': 'http://twitter.com/search?q=CLANNAD',
#     'promoted_content': None,
#     'query': 'CLANNAD',
#     'tweet_volume': 34229},
#    {'name': 'ハルヒ',
#     'url': 'http://twitter.com/search?q=%E3%83%8F%E3%83%AB%E3%83%92',
#     'promoted_content': None,
#     'query': '%E3%83%8F%E3%83%AB%E3%83%92',
#     'tweet_volume': 56653},
#    {'name': 'Kyoto Animation',
#     'url': 'http://twitter.com/search?q=%22Kyoto+Animation%22',
#     'promoted_content': None,
#     'query': '%22Kyoto+Animation%22',
#     'tweet_volume': 161119},
#    {'name': 'çokuygunfiyattan ttverilir',
#     'url': 'http://twitter.com/search?q=%22%C3%A7okuygunfiyattan+ttverilir%22',
#     'promoted_content': None,
#     'query': '%22%C3%A7okuygunfiyattan+ttverilir%22',
#     'tweet_volume': None},
#    {'name': '犠牲者',
#     'url': 'http://twitter.com/search?q=%E7%8A%A0%E7%89%B2%E8%80%85',
#     'promoted_content': None,
#     'query': '%E7%8A%A0%E7%89%B2%E8%80%85',
#     'tweet_volume': 141427},
#    {'name': '放火事件',
#     'url': 'http://twitter.com/search?q=%E6%94%BE%E7%81%AB%E4%BA%8B%E4%BB%B6',
#     'promoted_content': None,
#     'query': '%E6%94%BE%E7%81%AB%E4%BA%8B%E4%BB%B6',
#     'tweet_volume': 406286},
#    {'name': '쿄애니',
#     'url': 'http://twitter.com/search?q=%EC%BF%84%EC%95%A0%EB%8B%88',
#     'promoted_content': None,
#     'query': '%EC%BF%84%EC%95%A0%EB%8B%88',
#     'tweet_volume': 90134},
#    {'name': '京都アニメーション',
#     'url': 'http://twitter.com/search?q=%E4%BA%AC%E9%83%BD%E3%82%A2%E3%83%8B%E3%83%A1%E3%83%BC%E3%82%B7%E3%83%A7%E3%83%B3',
#     'promoted_content': None,
#     'query': '%E4%BA%AC%E9%83%BD%E3%82%A2%E3%83%8B%E3%83%A1%E3%83%BC%E3%82%B7%E3%83%A7%E3%83%B3',
#     'tweet_volume': 975181},
#    {'name': 'SuçYok DemagojiVar',
#     'url': 'http://twitter.com/search?q=%22Su%C3%A7Yok+DemagojiVar%22',
#     'promoted_content': None,
#     'query': '%22Su%C3%A7Yok+DemagojiVar%22',
#     'tweet_volume': None},
#    {'name': '宮迫引退',
#     'url': 'http://twitter.com/search?q=%E5%AE%AE%E8%BF%AB%E5%BC%95%E9%80%80',
#     'promoted_content': None,
#     'query': '%E5%AE%AE%E8%BF%AB%E5%BC%95%E9%80%80',
#     'tweet_volume': 25747},
#    {'name': '署名活動',
#     'url': 'http://twitter.com/search?q=%E7%BD%B2%E5%90%8D%E6%B4%BB%E5%8B%95',
#     'promoted_content': None,
#     'query': '%E7%BD%B2%E5%90%8D%E6%B4%BB%E5%8B%95',
#     'tweet_volume': 29505},
#    {'name': '安否不明',
#     'url': 'http://twitter.com/search?q=%E5%AE%89%E5%90%A6%E4%B8%8D%E6%98%8E',
#     'promoted_content': None,
#     'query': '%E5%AE%89%E5%90%A6%E4%B8%8D%E6%98%8E',
#     'tweet_volume': 33588},
#    {'name': '死者数',
#     'url': 'http://twitter.com/search?q=%E6%AD%BB%E8%80%85%E6%95%B0',
#     'promoted_content': None,
#     'query': '%E6%AD%BB%E8%80%85%E6%95%B0',
#     'tweet_volume': 51491},
#    {'name': '境界の彼方',
#     'url': 'http://twitter.com/search?q=%E5%A2%83%E7%95%8C%E3%81%AE%E5%BD%BC%E6%96%B9',
#     'promoted_content': None,
#     'query': '%E5%A2%83%E7%95%8C%E3%81%AE%E5%BD%BC%E6%96%B9',
#     'tweet_volume': 20949},
#    {'name': 'ヴァイオレットエヴァーガーデン',
#     'url': 'http://twitter.com/search?q=%E3%83%B4%E3%82%A1%E3%82%A4%E3%82%AA%E3%83%AC%E3%83%83%E3%83%88%E3%82%A8%E3%83%B4%E3%82%A1%E3%83%BC%E3%82%AC%E3%83%BC%E3%83%87%E3%83%B3',
#     'promoted_content': None,
#     'query': '%E3%83%B4%E3%82%A1%E3%82%A4%E3%82%AA%E3%83%AC%E3%83%83%E3%83%88%E3%82%A8%E3%83%B4%E3%82%A1%E3%83%BC%E3%82%AC%E3%83%BC%E3%83%87%E3%83%B3',
#     'tweet_volume': 10354},
#    {'name': 'Long Flight',
#     'url': 'http://twitter.com/search?q=%22Long+Flight%22',
#     'promoted_content': None,
#     'query': '%22Long+Flight%22',
#     'tweet_volume': 131135},
#    {'name': '地下鉄サリン事件',
#     'url': 'http://twitter.com/search?q=%E5%9C%B0%E4%B8%8B%E9%89%84%E3%82%B5%E3%83%AA%E3%83%B3%E4%BA%8B%E4%BB%B6',
#     'promoted_content': None,
#     'query': '%E5%9C%B0%E4%B8%8B%E9%89%84%E3%82%B5%E3%83%AA%E3%83%B3%E4%BA%8B%E4%BB%B6',
#     'tweet_volume': 14538},
#    {'name': 'ユーフォニアム',
#     'url': 'http://twitter.com/search?q=%E3%83%A6%E3%83%BC%E3%83%95%E3%82%A9%E3%83%8B%E3%82%A2%E3%83%A0',
#     'promoted_content': None,
#     'query': '%E3%83%A6%E3%83%BC%E3%83%95%E3%82%A9%E3%83%8B%E3%82%A2%E3%83%A0',
#     'tweet_volume': 22980},
#    {'name': '死者16人',
#     'url': 'http://twitter.com/search?q=%E6%AD%BB%E8%80%8516%E4%BA%BA',
#     'promoted_content': None,
#     'query': '%E6%AD%BB%E8%80%8516%E4%BA%BA',
#     'tweet_volume': None},
#    {'name': '#FelizJueves',
#     'url': 'http://twitter.com/search?q=%23FelizJueves',
#     'promoted_content': None,
#     'query': '%23FelizJueves',
#     'tweet_volume': 15111},
#    {'name': '#VS嵐',
#     'url': 'http://twitter.com/search?q=%23VS%E5%B5%90',
#     'promoted_content': None,
#     'query': '%23VS%E5%B5%90',
#     'tweet_volume': 13184},
#    {'name': '#れいわ祭2',
#     'url': 'http://twitter.com/search?q=%23%E3%82%8C%E3%81%84%E3%82%8F%E7%A5%AD2',
#     'promoted_content': None,
#     'query': '%23%E3%82%8C%E3%81%84%E3%82%8F%E7%A5%AD2',
#     'tweet_volume': None},
#    {'name': '#sgkDMDlicihazınıalamıyor',
#     'url': 'http://twitter.com/search?q=%23sgkDMDlicihaz%C4%B1n%C4%B1alam%C4%B1yor',
#     'promoted_content': None,
#     'query': '%23sgkDMDlicihaz%C4%B1n%C4%B1alam%C4%B1yor',
#     'tweet_volume': 12415},
#    {'name': '#MandelaDay2019',
#     'url': 'http://twitter.com/search?q=%23MandelaDay2019',
#     'promoted_content': None,
#     'query': '%23MandelaDay2019',
#     'tweet_volume': 14165},
#    {'name': '#ShahidKhaqanAbbasi',
#     'url': 'http://twitter.com/search?q=%23ShahidKhaqanAbbasi',
#     'promoted_content': None,
#     'query': '%23ShahidKhaqanAbbasi',
#     'tweet_volume': 11454},
#    {'name': '#CarrerasOsorio19',
#     'url': 'http://twitter.com/search?q=%23CarrerasOsorio19',
#     'promoted_content': None,
#     'query': '%23CarrerasOsorio19',
#     'tweet_volume': None},
#    {'name': '#ThursdayThoughts',
#     'url': 'http://twitter.com/search?q=%23ThursdayThoughts',
#     'promoted_content': None,
#     'query': '%23ThursdayThoughts',
#     'tweet_volume': 31299},
#    {'name': '#KYKBorcuBelimiziBüktü',
#     'url': 'http://twitter.com/search?q=%23KYKBorcuBelimiziB%C3%BCkt%C3%BC',
#     'promoted_content': None,
#     'query': '%23KYKBorcuBelimiziB%C3%BCkt%C3%BC',
#     'tweet_volume': None},
#    {'name': '#消費税廃止',
#     'url': 'http://twitter.com/search?q=%23%E6%B6%88%E8%B2%BB%E7%A8%8E%E5%BB%83%E6%AD%A2',
#     'promoted_content': None,
#     'query': '%23%E6%B6%88%E8%B2%BB%E7%A8%8E%E5%BB%83%E6%AD%A2',
#     'tweet_volume': 19702},
#    {'name': '#グサッとアカデミア',
#     'url': 'http://twitter.com/search?q=%23%E3%82%B0%E3%82%B5%E3%83%83%E3%81%A8%E3%82%A2%E3%82%AB%E3%83%87%E3%83%9F%E3%82%A2',
#     'promoted_content': None,
#     'query': '%23%E3%82%B0%E3%82%B5%E3%83%83%E3%81%A8%E3%82%A2%E3%82%AB%E3%83%87%E3%83%9F%E3%82%A2',
#     'tweet_volume': None},
#    {'name': '#نتايج_القدره_المعرفيه',
#     'url': 'http://twitter.com/search?q=%23%D9%86%D8%AA%D8%A7%D9%8A%D8%AC_%D8%A7%D9%84%D9%82%D8%AF%D8%B1%D9%87_%D8%A7%D9%84%D9%85%D8%B9%D8%B1%D9%81%D9%8A%D9%87',
#     'promoted_content': None,
#     'query': '%23%D9%86%D8%AA%D8%A7%D9%8A%D8%AC_%D8%A7%D9%84%D9%82%D8%AF%D8%B1%D9%87_%D8%A7%D9%84%D9%85%D8%B9%D8%B1%D9%81%D9%8A%D9%87',
#     'tweet_volume': None},
#    {'name': '#MissionMangalTrailer',
#     'url': 'http://twitter.com/search?q=%23MissionMangalTrailer',
#     'promoted_content': None,
#     'query': '%23MissionMangalTrailer',
#     'tweet_volume': 19095},
#    {'name': '#닉네임_끝을_스로_바꾸면_쿨해진다',
#     'url': 'http://twitter.com/search?q=%23%EB%8B%89%EB%84%A4%EC%9E%84_%EB%81%9D%EC%9D%84_%EC%8A%A4%EB%A1%9C_%EB%B0%94%EA%BE%B8%EB%A9%B4_%EC%BF%A8%ED%95%B4%EC%A7%84%EB%8B%A4',
#     'promoted_content': None,
#     'query': '%23%EB%8B%89%EB%84%A4%EC%9E%84_%EB%81%9D%EC%9D%84_%EC%8A%A4%EB%A1%9C_%EB%B0%94%EA%BE%B8%EB%A9%B4_%EC%BF%A8%ED%95%B4%EC%A7%84%EB%8B%A4',
#     'tweet_volume': None},
#    {'name': '#TheOpen',
#     'url': 'http://twitter.com/search?q=%23TheOpen',
#     'promoted_content': None,
#     'query': '%23TheOpen',
#     'tweet_volume': 30518},
#    {'name': '#انفصال_احلام_عن_زوجها',
#     'url': 'http://twitter.com/search?q=%23%D8%A7%D9%86%D9%81%D8%B5%D8%A7%D9%84_%D8%A7%D8%AD%D9%84%D8%A7%D9%85_%D8%B9%D9%86_%D8%B2%D9%88%D8%AC%D9%87%D8%A7',
#     'promoted_content': None,
#     'query': '%23%D8%A7%D9%86%D9%81%D8%B5%D8%A7%D9%84_%D8%A7%D8%AD%D9%84%D8%A7%D9%85_%D8%B9%D9%86_%D8%B2%D9%88%D8%AC%D9%87%D8%A7',
#     'tweet_volume': 22843},
#    {'name': '#プレバト',
#     'url': 'http://twitter.com/search?q=%23%E3%83%97%E3%83%AC%E3%83%90%E3%83%88',
#     'promoted_content': None,
#     'query': '%23%E3%83%97%E3%83%AC%E3%83%90%E3%83%88',
#     'tweet_volume': None},
#    {'name': '#NRLBroncosBulldogs',
#     'url': 'http://twitter.com/search?q=%23NRLBroncosBulldogs',
#     'promoted_content': None,
#     'query': '%23NRLBroncosBulldogs',
#     'tweet_volume': None},
#    {'name': '#GananLosCongresistas',
#     'url': 'http://twitter.com/search?q=%23GananLosCongresistas',
#     'promoted_content': None,
#     'query': '%23GananLosCongresistas',
#     'tweet_volume': None},
#    {'name': '#AMIA25años',
#     'url': 'http://twitter.com/search?q=%23AMIA25a%C3%B1os',
#     'promoted_content': None,
#     'query': '%23AMIA25a%C3%B1os',
#     'tweet_volume': None},
#    {'name': '#TLに猫を流す',
#     'url': 'http://twitter.com/search?q=%23TL%E3%81%AB%E7%8C%AB%E3%82%92%E6%B5%81%E3%81%99',
#     'promoted_content': None,
#     'query': '%23TL%E3%81%AB%E7%8C%AB%E3%82%92%E6%B5%81%E3%81%99',
#     'tweet_volume': None},
#    {'name': '#MAYMAYGandangGanDOLL',
#     'url': 'http://twitter.com/search?q=%23MAYMAYGandangGanDOLL',
#     'promoted_content': None,
#     'query': '%23MAYMAYGandangGanDOLL',
#     'tweet_volume': 50049},
#    {'name': '#perşembe',
#     'url': 'http://twitter.com/search?q=%23per%C5%9Fembe',
#     'promoted_content': None,
#     'query': '%23per%C5%9Fembe',
#     'tweet_volume': 21154}],
#   'as_of': '2019-07-18T12:02:59Z',
#   'created_at': '2019-07-18T11:55:47Z',
#   'locations': [{'name': 'Worldwide', 'woeid': 1}]}]

# %%
trends=local_trends
print(type(trends))
print(list(trends[0].keys()))
print(trends[0]['trends'])
# Out:
# <class 'twitter.api.TwitterListResponse'>
# ['trends', 'as_of', 'created_at', 'locations']
# [{'name': '#WhatsAppDown', 'url': 'http://twitter.com/search?q=%23WhatsAppDown', 'promoted_content': None, 'query': '%23WhatsAppDown', 'tweet_volume': 144552}, {'name': '#ENGvNZ', 'url': 'http://twitter.com/search?q=%23ENGvNZ', 'promoted_content': None, 'query': '%23ENGvNZ', 'tweet_volume': 72417}, {'name': '#RahulGandhi', 'url': 'http://twitter.com/search?q=%23RahulGandhi', 'promoted_content': None, 'query': '%23RahulGandhi', 'tweet_volume': 16185}, {'name': 'Manjrekar', 'url': 'http://twitter.com/search?q=Manjrekar', 'promoted_content': None, 'query': 'Manjrekar', 'tweet_volume': 18238}, {'name': '#GoGreen_SayNoToPolythene', 'url': 'http://twitter.com/search?q=%23GoGreen_SayNoToPolythene', 'promoted_content': None, 'query': '%23GoGreen_SayNoToPolythene', 'tweet_volume': 20703}, {'name': 'Jaddu', 'url': 'http://twitter.com/search?q=Jaddu', 'promoted_content': None, 'query': 'Jaddu', 'tweet_volume': None}, {'name': '#1992MeinBhi', 'url': 'http://twitter.com/search?q=%231992MeinBhi', 'promoted_content': None, 'query': '%231992MeinBhi', 'tweet_volume': None}, {'name': 'Sanjay', 'url': 'http://twitter.com/search?q=Sanjay', 'promoted_content': None, 'query': 'Sanjay', 'tweet_volume': 22643}, {'name': 'Mark Zuckerberg', 'url': 'http://twitter.com/search?q=%22Mark+Zuckerberg%22', 'promoted_content': None, 'query': '%22Mark+Zuckerberg%22', 'tweet_volume': 44647}, {'name': 'Mihir', 'url': 'http://twitter.com/search?q=Mihir', 'promoted_content': None, 'query': 'Mihir', 'tweet_volume': None}, {'name': 'Twitter DM', 'url': 'http://twitter.com/search?q=%22Twitter+DM%22', 'promoted_content': None, 'query': '%22Twitter+DM%22', 'tweet_volume': None}, {'name': 'Server', 'url': 'http://twitter.com/search?q=Server', 'promoted_content': None, 'query': 'Server', 'tweet_volume': 40216}, {'name': 'Mark Wood', 'url': 'http://twitter.com/search?q=%22Mark+Wood%22', 'promoted_content': None, 'query': '%22Mark+Wood%22', 'tweet_volume': None}, {'name': 'Ned Leeds', 'url': 'http://twitter.com/search?q=%22Ned+Leeds%22', 'promoted_content': None, 'query': '%22Ned+Leeds%22', 'tweet_volume': None}, {'name': 'Motilal Vora', 'url': 'http://twitter.com/search?q=%22Motilal+Vora%22', 'promoted_content': None, 'query': '%22Motilal+Vora%22', 'tweet_volume': None}, {'name': 'Aus and India', 'url': 'http://twitter.com/search?q=%22Aus+and+India%22', 'promoted_content': None, 'query': '%22Aus+and+India%22', 'tweet_volume': None}, {'name': 'Parody', 'url': 'http://twitter.com/search?q=Parody', 'promoted_content': None, 'query': 'Parody', 'tweet_volume': 19968}, {'name': 'Commentator', 'url': 'http://twitter.com/search?q=Commentator', 'promoted_content': None, 'query': 'Commentator', 'tweet_volume': 10258}, {'name': '#KadaramKondanTrailer', 'url': 'http://twitter.com/search?q=%23KadaramKondanTrailer', 'promoted_content': None, 'query': '%23KadaramKondanTrailer', 'tweet_volume': None}, {'name': '#AmbatiRayuduRetires', 'url': 'http://twitter.com/search?q=%23AmbatiRayuduRetires', 'promoted_content': None, 'query': '%23AmbatiRayuduRetires', 'tweet_volume': None}, {'name': '#FortuneDhanushBdayIn25Days', 'url': 'http://twitter.com/search?q=%23FortuneDhanushBdayIn25Days', 'promoted_content': None, 'query': '%23FortuneDhanushBdayIn25Days', 'tweet_volume': 72639}, {'name': '#SirikiSingle', 'url': 'http://twitter.com/search?q=%23SirikiSingle', 'promoted_content': None, 'query': '%23SirikiSingle', 'tweet_volume': 27723}, {'name': '#DelhiTempleAttack', 'url': 'http://twitter.com/search?q=%23DelhiTempleAttack', 'promoted_content': None, 'query': '%23DelhiTempleAttack', 'tweet_volume': None}, {'name': '#FarFromHomeWithMNX', 'url': 'http://twitter.com/search?q=%23FarFromHomeWithMNX', 'promoted_content': None, 'query': '%23FarFromHomeWithMNX', 'tweet_volume': None}, {'name': '#Sherin', 'url': 'http://twitter.com/search?q=%23Sherin', 'promoted_content': None, 'query': '%23Sherin', 'tweet_volume': None}, {'name': '#50DaysForTFIEmperorChiruBday', 'url': 'http://twitter.com/search?q=%2350Day ...

# %% [markdown]
# ## Example 3. Displaying API responses as pretty-printed JSON

# %%
import json

print((json.dumps(us_trends[:2], indent=1)))
# Out:
# [
#  {
#   "trends": [
#    {
#     "name": "#MissionMangalTrailer",
#     "url": "http://twitter.com/search?q=%23MissionMangalTrailer",
#     "promoted_content": null,
#     "query": "%23MissionMangalTrailer",
#     "tweet_volume": 19095
#    },
#    {
#     "name": "#KarnatakaFloorTest",
#     "url": "http://twitter.com/search?q=%23KarnatakaFloorTest",
#     "promoted_content": null,
#     "query": "%23KarnatakaFloorTest",
#     "tweet_volume": null
#    },
#    {
#     "name": "#RainRaider",
#     "url": "http://twitter.com/search?q=%23RainRaider",
#     "promoted_content": null,
#     "query": "%23RainRaider",
#     "tweet_volume": null
#    },
#    {
#     "name": "#SilsilaOnVoot",
#     "url": "http://twitter.com/search?q=%23SilsilaOnVoot",
#     "promoted_content": null,
#     "query": "%23SilsilaOnVoot",
#     "tweet_volume": null
#    },
#    {
#     "name": "#LifeChangingPlaces",
#     "url": "http://twitter.com/search?q=%23LifeChangingPlaces",
#     "promoted_content": null,
#     "query": "%23LifeChangingPlaces",
#     "tweet_volume": null
#    },
#    {
#     "name": "Trevor Bayliss",
#     "url": "http://twitter.com/search?q=%22Trevor+Bayliss%22",
#     "promoted_content": null,
#     "query": "%22Trevor+Bayliss%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Tom Moody",
#     "url": "http://twitter.com/search?q=%22Tom+Moody%22",
#     "promoted_content": null,
#     "query": "%22Tom+Moody%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Rs 400",
#     "url": "http://twitter.com/search?q=%22Rs+400%22",
#     "promoted_content": null,
#     "query": "%22Rs+400%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Hampi",
#     "url": "http://twitter.com/search?q=Hampi",
#     "promoted_content": null,
#     "query": "Hampi",
#     "tweet_volume": null
#    },
#    {
#     "name": "Ian Chappell",
#     "url": "http://twitter.com/search?q=%22Ian+Chappell%22",
#     "promoted_content": null,
#     "query": "%22Ian+Chappell%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Hanuman Chalisa",
#     "url": "http://twitter.com/search?q=%22Hanuman+Chalisa%22",
#     "promoted_content": null,
#     "query": "%22Hanuman+Chalisa%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Raveesh Kumar",
#     "url": "http://twitter.com/search?q=%22Raveesh+Kumar%22",
#     "promoted_content": null,
#     "query": "%22Raveesh+Kumar%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Can I DM",
#     "url": "http://twitter.com/search?q=%22Can+I+DM%22",
#     "promoted_content": null,
#     "query": "%22Can+I+DM%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Rizwan Kaskar",
#     "url": "http://twitter.com/search?q=%22Rizwan+Kaskar%22",
#     "promoted_content": null,
#     "query": "%22Rizwan+Kaskar%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "#KaappaanSecondSingle",
#     "url": "http://twitter.com/search?q=%23KaappaanSecondSingle",
#     "promoted_content": null,
#     "query": "%23KaappaanSecondSingle",
#     "tweet_volume": 12753
#    },
#    {
#     "name": "#HimaDas",
#     "url": "http://twitter.com/search?q=%23HimaDas",
#     "promoted_content": null,
#     "query": "%23HimaDas",
#     "tweet_volume": null
#    },
#    {
#     "name": "#AjazKhan",
#     "url": "http://twitter.com/search?q=%23AjazKhan",
#     "promoted_content": null,
#     "query": "%23AjazKhan",
#     "tweet_volume": null
#    },
#    {
#     "name": "#EkSiwaTere",
#     "url": "http://twitter.com/search?q=%23EkSiwaTere",
#     "promoted_content": null,
#     "query": "%23EkSiwaTere",
#     "tweet_volume": null
#    },
#    {
#     "name": "#ismartshankarday",
#     "url": "http://twitter.com/search?q=%23ismartshankarday",
#     "promoted_content": null,
#     "query": "%23ismartshankarday",
#     "tweet_volume": null
#    },
#    {
#     "name": "#alpeshthakor",
#     "url": "http://twitter.com/search?q=%23alpeshthakor",
#     "promoted_content": null,
#     "query": "%23alpeshthakor",
#     "tweet_volume": null
#    },
#    {
#     "name": "#NelsonMandela",
#     "url": "http://twitter.com/search?q=%23NelsonMandela",
#     "promoted_content": null,
#     "query": "%23NelsonMandela",
#     "tweet_volume": 11518
#    },
#    {
#     "name": "#Rakshasudu",
#     "url": "http://twitter.com/search?q=%23Rakshasudu",
#     "promoted_content": null,
#     "query": "%23Rakshasudu",
#     "tweet_volume": null
#    },
#    {
#     "name": "#shahidkhaqanabbasi",
#     "url": "http://twitter.com/search?q=%23shahidkhaqanabbasi",
#     "promoted_content": null,
#     "query": "%23shahidkhaqanabbasi",
#     "tweet_volume": 11456
#    },
#    {
#     "name": "#instagramlikes",
#     "url": "http://twitter.com/search?q=%23instagramlikes",
#     "promoted_content": null,
#     "query": "%23instagramlikes",
#     "tweet_volume": null
#    },
#    {
#     "name": "#DearComradeAnthem",
#     "url": "http://twitter.com/search?q=%23DearComradeAnthem",
#     "promoted_content": null,
#     "query": "%23DearComradeAnthem",
#     "tweet_volume": null
#    },
#    {
#     "name": "#StepDownCM",
#     "url": "http://twitter.com/search?q=%23StepDownCM",
#     "promoted_content": null,
#     "query": "%23StepDownCM",
#     "tweet_volume": null
#    },
#    {
#     "name": "#TheLionKingContestOnBOI",
#     "url": "http://twitter.com/search?q=%23TheLionKingContestOnBOI",
#     "promoted_content": null,
#     "query": "%23TheLionKingContestOnBOI",
#     "tweet_volume": null
#    },
#    {
#     "name": "#KKFromTomorrow",
#     "url": "http://twitter.com/search?q=%23KKFromTomorrow",
#     "promoted_content": null,
#     "query": "%23KKFromTomorrow",
#     "tweet_volume": null
#    },
#    {
#     "name": "#DhoondeAkhiyaan",
#     "url": "http://twitter.com/search?q=%23DhoondeAkhiyaan",
#     "promoted_content": null,
#     "query": "%23DhoondeAkhiyaan",
#     "tweet_volume": null
#    },
#    {
#     "name": "#taekookersgoingtojailparty",
#     "url": "http://twitter.com/search?q=%23taekookersgoingtojailparty",
#     "promoted_content": null,
#     "query": "%23taekookersgoingtojailparty",
#     "tweet_volume": 44464
#    },
#    {
#     "name": "#TAEYONG_LongFlight",
#     "url": "http://twitter.com/search?q=%23TAEYONG_LongFlight",
#     "promoted_content": null,
#     "query": "%23TAEYONG_LongFlight",
#     "tweet_volume": 207234
#    },
#    {
#     "name": "#HappyBirthdayPriyankaChopra",
#     "url": "http://twitter.com/search?q=%23HappyBirthdayPriyankaChopra",
#     "promoted_content": null,
#     "query": "%23HappyBirthdayPriyankaChopra",
#     "tweet_volume": null
#    },
#    {
#     "name": "#ChennaiPalaniMars",
#     "url": "http://twitter.com/search?q=%23ChennaiPalaniMars",
#     "promoted_content": null,
#     "query": "%23ChennaiPalaniMars",
#     "tweet_volume": null
#    },
#    {
#     "name": "#faceappchallange",
#     "url": "http://twitter.com/search?q=%23faceappchallange",
#     "promoted_content": null,
#     "query": "%23faceappchallange",
#     "tweet_volume": null
#    },
#    {
#     "name": "#HopeProductions",
#     "url": "http://twitter.com/search?q=%23HopeProductions",
#     "promoted_content": null,
#     "query": "%23HopeProductions",
#     "tweet_volume": null
#    },
#    {
#     "name": "#TAMANNAAHsNext",
#     "url": "http://twitter.com/search?q=%23TAMANNAAHsNext",
#     "promoted_content": null,
#     "query": "%23TAMANNAAHsNext",
#     "tweet_volume": null
#    },
#    {
#     "name": "#HappyBirthdaySmritiMandhana",
#     "url": "http://twitter.com/search?q=%23HappyBirthdaySmritiMandhana",
#     "promoted_content": null,
#     "query": "%23HappyBirthdaySmritiMandhana",
#     "tweet_volume": null
#    },
#    {
#     "name": "#GabriellaDemetriades",
#     "url": "http://twitter.com/search?q=%23GabriellaDemetriades",
#     "promoted_content": null,
#     "query": "%23GabriellaDemetriades",
#     "tweet_volume": null
#    },
#    {
#     "name": "#PrayForKyoani",
#     "url": "http://twitter.com/search?q=%23PrayForKyoani",
#     "promoted_content": null,
#     "query": "%23PrayForKyoani",
#     "tweet_volume": 125724
#    },
#    {
#     "name": "#SaravanaBhavan",
#     "url": "http://twitter.com/search?q=%23SaravanaBhavan",
#     "promoted_content": null,
#     "query": "%23SaravanaBhavan",
#     "tweet_volume": null
#    },
#    {
#     "name": "#Tenkasi",
#     "url": "http://twitter.com/search?q=%23Tenkasi",
#     "promoted_content": null,
#     "query": "%23Tenkasi",
#     "tweet_volume": null
#    },
#    {
#     "name": "#KyotoAnimation",
#     "url": "http://twitter.com/search?q=%23KyotoAnimation",
#     "promoted_content": null,
#     "query": "%23KyotoAnimation",
#     "tweet_volume": null
#    },
#    {
#     "name": "#ConspiraciesAgainstHinduism",
#     "url": "http://twitter.com/search?q=%23ConspiraciesAgainstHinduism",
#     "promoted_content": null,
#     "query": "%23ConspiraciesAgainstHinduism",
#     "tweet_volume": 28268
#    },
#    {
#     "name": "#WomensAshes",
#     "url": "http://twitter.com/search?q=%23WomensAshes",
#     "promoted_content": null,
#     "query": "%23WomensAshes",
#     "tweet_volume": null
#    },
#    {
#     "name": "#MGHector",
#     "url": "http://twitter.com/search?q=%23MGHector",
#     "promoted_content": null,
#     "query": "%23MGHector",
#     "tweet_volume": null
#    },
#    {
#     "name": "#Ezra",
#     "url": "http://twitter.com/search?q=%23Ezra",
#     "promoted_content": null,
#     "query": "%23Ezra",
#     "tweet_volume": null
#    },
#    {
#     "name": "#5YearsOfBlockBusterVIP",
#     "url": "http://twitter.com/search?q=%235YearsOfBlockBusterVIP",
#     "promoted_content": null,
#     "query": "%235YearsOfBlockBusterVIP",
#     "tweet_volume": null
#    },
#    {
#     "name": "#HappyBirthdayBhumiPednekar",
#     "url": "http://twitter.com/search?q=%23HappyBirthdayBhumiPednekar",
#     "promoted_content": null,
#     "query": "%23HappyBirthdayBhumiPednekar",
#     "tweet_volume": null
#    },
#    {
#     "name": "#Helo",
#     "url": "http://twitter.com/search?q=%23Helo",
#     "promoted_content": null,
#     "query": "%23Helo",
#     "tweet_volume": null
#    },
#    {
#     "name": "#whatalife",
#     "url": "http://twitter.com/search?q=%23whatalife",
#     "promoted_content": null,
#     "query": "%23whatalife",
#     "tweet_volume": 204072
#    }
#   ],
#   "as_of": "2019-07-18T12:03:00Z",
#   "created_at": "2019-07-18T11:55:48Z",
#   "locations": [
#    {
#     "name": "India",
#     "woeid": 23424848
#    }
#   ]
#  }
# ]

# %% [markdown]
# ## Example 4. Computing the intersection of two sets of trends

# %%
trends_set = {}
trends_set['world'] = set([trend['name'] 
                        for trend in world_trends[0]['trends']])

trends_set['us'] = set([trend['name'] 
                     for trend in us_trends[0]['trends']]) 

trends_set['san diego'] = set([trend['name'] 
                     for trend in local_trends[0]['trends']])

# %%
for loc in ['world','us','san diego']:
    print(('-'*10,loc))
    print((','.join(trends_set[loc])))
# Out:
# ('----------', 'world')
# #EfendiBirgünBeniUnutursun,彼方のアストラ,MehmetÖzere BetsatSponsor,ruletturnuvası ligobet40ta,Boban,#FelizMiercoles,BirkezDaha SusDediler,Héctor Herrera,#살다살다뭐닮았다고들어본경험,#ไอจีล่ม,#BRINGTHESOUL_THEMOVIE,#زواج_ابو_فريح,Happy 4th of July,O Instagram,#TürkiyeTürkiyedenBüyüktür,Zuckerberg,#الواتساب_معلق,#Stromboli,Ip Man,#BoycottTrump4thOfJuly,#3Jul,#تمثال_الحريه,シンデレラガール,#çöktü,#ENGvNZ,#SüresizSözleşmeliyiDuyReis,IG and FB,Jim Beam,#realişçileri23aydırmücadelede,#AVAxNCT127,#TanışmaBaşlatanCümleler,#DünyaNeresi,#乃木坂46ANN,#탐라_장래희망_자랑,cinselistismar iftirası,#fumou954,#PBB8SecondBigJumper,Tarımİşsiz Bakanİlgisiz,インスタ不具合,#هات_نكته_تضحك,#whatsappdown,Twitter DMs,#الترفيه_تستضيف_مغنيه_اباحيه,#SamsunAtakumSahildeyiz,Chandler Parsons,#PedroResponde,Donnie Yen,#في_اي_مدينه_مولود,#増田貴久誕生祭,#LollaAR
# ('----------', 'us')
# #FortuneDhanushBdayIn25Days,Jaddu,#BRINGTHESOUL_THEMOVIE,Mihir,Parody,#GoGreen_SayNoToPolythene,Server,Sanjay,#RahulGandhi,#BKBirla,Twitter DM,#1992MeinBhi,#ENGvNZ,#50DaysForTFIEmperorChiruBday,#KadaramKondanTrailer,Motilal Vora,#RahulStepsDown,Mark Wood,Congress President,#PsychoSaiyaan,#WhatsAppDown,Manjrekar,#FarFromHomeWithMNX,#Blogchatter,#YamahaFZ25,#Sherin,#SirikiSingle,Aus and India,#BackTheBlackCaps,Rodri,Mark Zuckerberg,#AmbatiRayuduRetires,#AUSvsNZ,#HafizSaeed,#DelhiTempleAttack,Ned Leeds
# ('----------', 'san diego')
# #FortuneDhanushBdayIn25Days,Jaddu,#BRINGTHESOUL_THEMOVIE,Mihir,Parody,#GoGreen_SayNoToPolythene,Server,#shameonbcci,Sanjay,#RahulGandhi,#BKBirla,#1992MeinBhi,Twitter DM,#ENGvNZ,#50DaysForTFIEmperorChiruBday,#KadaramKondanTrailer,Motilal Vora,Mark Wood,Manjrekar,#WhatsAppDown,#FarFromHomeWithMNX,#Blogchatter,#YamahaFZ25,Commentator,#Sherin,#SirikiSingle,Aus and India,#BackTheBlackCaps,Mark Zuckerberg,#AmbatiRayuduRetires,#AUSvsNZ,#HafizSaeed,#DelhiTempleAttack,Ned Leeds

# %%
print(( '='*10,'intersection of world and us'))
print((trends_set['world'].intersection(trends_set['us'])))

print(('='*10,'intersection of us and san-diego'))
print((trends_set['san diego'].intersection(trends_set['us'])))
# Out:
# ('==========', 'intersection of world and us')
# {'#BRINGTHESOUL_THEMOVIE', '#ENGvNZ'}
# ('==========', 'intersection of us and san-diego')
# {'#FortuneDhanushBdayIn25Days', 'Jaddu', '#BRINGTHESOUL_THEMOVIE', 'Mihir', 'Parody', '#GoGreen_SayNoToPolythene', 'Server', 'Sanjay', '#RahulGandhi', '#BKBirla', '#1992MeinBhi', 'Twitter DM', '#ENGvNZ', '#50DaysForTFIEmperorChiruBday', '#KadaramKondanTrailer', 'Motilal Vora', 'Mark Wood', '#WhatsAppDown', 'Manjrekar', '#FarFromHomeWithMNX', '#Blogchatter', '#YamahaFZ25', '#SirikiSingle', 'Aus and India', '#BackTheBlackCaps', 'Ned Leeds', 'Mark Zuckerberg', '#AmbatiRayuduRetires', '#AUSvsNZ', '#HafizSaeed', '#DelhiTempleAttack', '#Sherin'}

# %% [markdown]
# ## Example 5. Collecting search results

# %% [markdown]
# Set the variable `q` to a trending topic,
# or anything else for that matter. The example query below
# was a trending topic when this content was being developed
# and is used throughout the remainder of this chapter

# %%
q = '#CWC19' 

number = 100

# See https://dev.twitter.com/docs/api/1.1/get/search/tweets

search_results = twitter_api.search.tweets(q=q, count=number)

statuses = search_results['statuses']

# %%
print(len(statuses))
print(statuses)
# Out:
# 100
# [{'created_at': 'Thu Jul 18 12:27:10 +0000 2019', 'id': 1151830771453313026, 'id_str': '1151830771453313026', 'text': 'RT @_cricingif: In the end, the world went home only with ifs and buts and the trophy stayed with the creators of the game, England #CWC19…', 'truncated': False, 'entities': {'hashtags': [{'text': 'CWC19', 'indices': [132, 138]}], 'symbols': [], 'user_mentions': [{'screen_name': '_cricingif', 'name': 'Cricingif', 'id': 710017952297394176, 'id_str': '710017952297394176', 'indices': [3, 14]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 4871616651, 'id_str': '4871616651', 'name': 'Taqi Zaidi', 'screen_name': 'TaqiTzaidi7214', 'location': 'اسلام آباد, پاکستان', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 440, 'friends_count': 1579, 'listed_count': 3, 'created_at': 'Tue Feb 02 12:52:53 +0000 2016', 'favourites_count': 68511, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 22154, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/858237380997795840/Rt9cmgtq_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/858237380997795840/Rt9cmgtq_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4871616651/1493454932', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Thu Jul 18 11:12:29 +0000 2019', 'id': 1151811978547081216, 'id_str': '1151811978547081216', 'text': 'In the end, the world went home only with ifs and buts and the trophy stayed with the creators of the game, England… https://t.co/YdmdtFDnsu', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/YdmdtFDnsu', 'expanded_url': 'https://twitter.com/i/web/status/1151811978547081216', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 710017952297394176, 'id_str': '710017952297394176', 'name': 'Cricingif', 'screen_name': '_cricingif', 'location': '', 'description': 'Official account of Cricingif - The fastest ball-by-ball coverage and live cricket highlights!', 'url': 'https://t.co/Jk3rqmYs2X', 'entities': {'url': {'urls': [{'url': 'https://t.co/Jk3rqmYs2X', 'expanded_url': 'http://www.cricingif.com', 'display_url': 'cricingif.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 53057, 'friends_count': 185, 'listed_count': 101, 'created_at': 'Wed Mar 16 08:20:46 +0000 2016', 'favourites_count': 19, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': True, 'statuses_count': 14848, 'lang': None, 'contributors_enabled': False, 'is_translator': ...

# %% [markdown]
# Twitter often returns duplicate results, we can filter them out checking for duplicate texts:

# %%
all_text = []
filtered_statuses = []
for s in statuses:
    if not s["text"] in all_text:
        filtered_statuses.append(s)
        all_text.append(s["text"])
statuses = filtered_statuses

# %%
len(statuses)
# Out:
# 84

# %%
[s['text'] for s in search_results['statuses']]
# Out:
# ["RT @SamMorshead_: England will compete in a World Cup semi-final on July 11 for the second time in two years, and this time the oppo won't…",
#  'RT @marooashish: @bira91 #GiveawayAlert #Bira91 #CWC19 @bira91\nwould love to party with \n@auk_sanejourno \n@Devanginee \n@ThakorVaishnavi \n\n#…',
#  'Jaa tujhee maaf kiya Dil ko tornay walay 💔\n#ENGvsNZ #CWC19 #Pakistani https://t.co/h6r1Rtyzpi',
#  'You sure are, unless you can defeat Bangladesh by at least 315 runs tomorrow. Good luck!\n#ENGvNZ #NZvENG #CWC19 https://t.co/nRccQDubiN',
#  'RT @deeputalks: For Pakistan to qualify:\nBeat Bangladesh by 311 runs after scoring 350\nBeat Bangladesh by 316 runs after scoring 400\nBeat B…',
#  '#JonnyBairstow’s second successive hundred laid the foundation for England’s 119-run thrashing of New Zealand that… https://t.co/ANRGjtn32W',
#  'RT @rgcricket: New Zealand 175-8 after 41 overs. Assuming NZ lose this game, the equation for Pakistan to qualify for semi-final:\n-Pak bat…',
#  'RT @ladywithflaws: Pakistanis doing nrr calculations to go through to semi finals. #EngvsNZ #CWC19 https://t.co/gguiroaCzq',
#  'In #PAKvBAN \nBangladesh won the toss🏏\n\nMortaza- "We like to .......\nSarfaraz-- "Bhai tu sabse pehle Hamari tickets… https://t.co/ebkGF98eG8',
#  'RT @iihtishamm: There’s no realistic possibility of Pakistan reaching to the Semifinals on NRR. #CWC19',
#  '#CWC19 sums up for #Pakistan! https://t.co/ei57wFVrl5',
#  'That one bloody rainy day against Sri lanka will haunt Pakistan for next 5 years. \n#CWC19 #NZvENG',
#  'RT @ShashiTharoor: Themost heartwarming story of #CWC19! https://t.co/LgHzDF9Tkz Well done @anandmahindra @imVkohli @ImRo45 !!',
#  'With 119 run win over NZ 🇳🇿, ENG 🏴\U000e0067\U000e0062\U000e0065\U000e006e\U000e0067\U000e007f have booked their place in the top 4 and have completed the line up for th… https://t.co/NnaOdneZxG',
#  "RT @cricketworldcup: This is the first time England have qualified for the World Cup semi-finals since '92\n\nThe similarities continue... 😛…",
#  'RT @Coral: ENGLAND WIN 🏴\U000e0067\U000e0062\U000e0065\U000e006e\U000e0067\U000e007f\n\nBeat India ✅\nBeat New Zealand ✅\nReach Semi-Finals ✅\n\nTwo wins away from World Cup glory 🏆\n\n#CWC19 https://t…',
#  "RT @sawerapasha: Its all over then.. Pakistan's world cup campaign comes to an end.. It was one hell of a ride of emotions, heart breaks, m…",
#  '“Inse hota hi nahi”  😂\n\n#1992MeinBhi #ENGvNZ #NZvENG #BackTheBlackCaps #WeAreEngland #CWC19 https://t.co/RYSWHOl2sa',
#  'RT @deeputalks: If Bangladesh opts to bat first on Friday, Pakistan stand eliminated even before a ball is bowled.\n\n#CWC19 #WeHaveWeWill',
#  'For #Pakistan to qualify in #CWC19:\nBeat Bangladesh by 311 runs after scoring 350\nBeat Ban by 316 runs ..scoring 40… https://t.co/8LMVZS3s0l',
#  'Can anyone confirm if Pakistan had defeated Bangladesh by huge margin in 1992?\n#ENGvNZ #NZvENG #CWC2019 #CWC19\nhttps://t.co/g5zPFkBSSt',
#  'Ab Tou Yahi Possible Hai K Pakistan 350 Score Kry Aur Bangladesh Team Is Duniya Se Hi Guzer Jaye Apni Innings Se Pehly Hi\n#PAKvBAN \n#CWC19',
#  'RT @im_asjad: Pori kainat ne Pakistan ko Semi final se dor karne ki koshish ki hai \n\nZare zare ne Pakistan ke khilaf sazish ki hai. \n\n#Cwc19',
#  'RT @primevideosport: Never in doubt! \n\n#England win by 1⃣1⃣9⃣ runs against #NewZealand and secure their place in the #CWC semi-final\n\n#WeAr…',
#  "Pakistan Can still reach in the semis if they can rename Dubai Int. Airport to 'Semi Final' \n\n#NZvENG #ENGvsNZ #CWC19",
#  'RT @bbctms: Kane Williamson, NZ captain: \n\n"England got the best of the conditions but they were the better team. They outplayed us in all…',
#  'RT @NorthStandGang: 2019 (to 1992) : Fuck off!\n🤷🏽\u200d♂\n#CWC19 #WeHaventWeWont  #ENGvNZ https://t.co/o2zdIJ9i39 https://t.co/GuyyvN4YIb',
#  "RT @cricketworldcup: This is the first time England have qualified for the World Cup semi-finals since '92\n\nThe similarities continue... 😛…",
#  'RT @saurabhs0607: Breaking: Imran khan have changed the name of lahore airport to semi-final. Pakistan will reach semi-final on 7th july😂😂😂…',
#  'England rise again. 🏴\U000e0067\U000e0062\U000e0065\U000e006e\U000e0067\U000e007f🦁 #ENGvNZ #CWC19',
#  'Jeetega bhai jeetega!!!! \nInnndiaaaa Jeetegaaa!!!🇮🇳🇮🇳💙💙💙 \n#CricketWorldCup2019 #CWC19 \n#ICCCricketWorldCup2019 #India #BleedBlue',
#  "RT @Boomrah_: It's not who you are.. What you do in life defines who you are.. Me not bothered if Pakistan gets to the semis or not but one…",
#  'RT @SaddamSama: - Meanwhile I am searching For Those People Jo Kehte The 1992 Mein Ye Hua Tha Wo Hua Tha 😁😂\n\n#ENGvNZُ #CWC19 #JustHumor htt…',
#  'RT @cricketworldcup: ENGLAND ARE INTO THE #CWC19 SEMI-FINALS!',
#  'RT @mohanstatsman: For Pakistan to reach #CWC19 SF, in their final match...\nbat first \nmake 400, and dismiss opponent for 84 and win by 316…',
#  'If Pakistan play with Blind Team of Bangladesh even then they cannot win with this margin what pak need.\n#CWC19',
#  'RT @TheRealPCB: Pakistan team training session at @HomeOfCricket.  \n\n#CWC19 #WeHaveWeWill https://t.co/V7T4KFdp8I',
#  '😍 This is the first time England have reached a World Cup semi-final since 1992!\n\nCould a World Cup finally be comi… https://t.co/VgyNmimszY',
#  "RT @cricketworldcup: This is the first time England have qualified for the World Cup semi-finals since '92\n\nThe similarities continue... 😛…",
#  'RT @rohitadhikari92: 😂😂😭\n#ENGvNZ #CWC19 https://t.co/6KNHGyGaSB',
#  'RT @iRashidLatif: Most predictable @icc #CWC19 World Cup ever . They turn million dollar game into billion dollar business. Remember the da…',
#  'RT @cricbuzz: England make it to the semi-finals of a World Cup for the first time since 1992\n\n#ENGvNZ #CWC19\n\nhttps://t.co/5MdagV7Lpd http…',
#  'RT @deeputalks: For Pakistan to qualify:\nBeat Bangladesh by 311 runs after scoring 350\nBeat Bangladesh by 316 runs after scoring 400\nBeat B…',
#  'RT @Coral: ENGLAND WIN 🏴\U000e0067\U000e0062\U000e0065\U000e006e\U000e0067\U000e007f\n\nBeat India ✅\nBeat New Zealand ✅\nReach Semi-Finals ✅\n\nTwo wins away from World Cup glory 🏆\n\n#CWC19 https://t…',
#  'RT @benjonescricket: Amazing how many pitches are flat when Bairstow and Roy are batting on it. #CWC19',
#  "So ENG Qualified For The Semis \n\nDon't Know About The Other Things \nBut #1992MeinBhiEsaHuaTha #CWC19",
#  "Could have been easier for Pakistan had that India vs NZ match wasn't a washout and won by India . #CWC19 &amp; #ENGvNZ",
#  'RT @acidkidrock: @RelianceFreshIN Here Comes My Perfect Screenshot.\n\n#INDvsBAN #CWC19 #RelianceFresh\n@RelianceFreshIN \n\nJoin \n@NishantJain_…',
#  '#England First time they reached semifinals since 1992 World Cup #ENGvNZ #CWC19',
#  '#ENGvNZ\nپاکستان بانوے میں بھی ورلڈ کپ فائنل نہیں ہارا تھا\n#CWC19',
#  "RT @cricketworldcup: This is the first time England have qualified for the World Cup semi-finals since '92\n\nThe similarities continue... 😛…",
#  'چار سو بننے والے نہیں اور نا ہی بنگالی 84 رنز پر آل آؤٹ ہونگے۔ مزہ تو تب آۓ گا جب بنـگالی ٹاس جیت کر بولیں گے۔ we w… https://t.co/EYI4r2Z0b9',
#  'RT @Shahrcasm: For Pakistan To Qualify...\n\nPehle Toss Jito\nFir 350-400 Banao\nFir Jaldi Out Karo..\n\nIs Se Acha Pizze Burger Khao, Aur Ghar J…',
#  'RT @OptaJim: 2 - Jonny Bairstow made a faster start than expected against New Zealand whilst Jason Roy implemented a more measured approach…',
#  'RT @ESPNcricinfo: Three semi-final spots are confirmed!\n\nThe fourth place will go to New Zealand unless Pakistan beat Bangladesh by a margi…',
#  '@bira91 My party buddies Are..\n@Devanginee\n@aakash_beast786\n@Heart_loverR\n\n#CWC19',
#  'RT @AmitShah: Congratulations to #TeamIndia for making into the semi-finals of the #CWC19. \n\nKudos to @ImRo45 for a perfect ton and @Jaspri…',
#  'Ajeeb Loog hain yai Indians..Pagal hoaay hain England kai jitnaay par; bhai humara choroo Apni fiqaar kero....Andaa… https://t.co/XlGEl8dEO7',
#  'RT @ANI: 87 year old Charulata Patel who was seen cheering for India in the stands during #BANvIND match: I have been watching cricket for…',
#  'RT @KamalPSP: Congratulations 🇵🇰 team on continuing the winning streak. It was a nail biting encounter today. Best wishes and prayers for S…',
#  'Job done 👏🏻 Who do want in the semi final then? Australia 🇦🇺 or India 🇮🇳?! \n#cwc19 #ENGvNZ  #ENG',
#  'Dear Neighbours \nI told you this is not 1992 \nThis is #CWC19 \nThe first challenge for you is to win the toss so bes… https://t.co/fq19V0GjMf',
#  'RT @deeputalks: If Bangladesh opts to bat first on Friday, Pakistan stand eliminated even before a ball is bowled.\n\n#CWC19 #WeHaveWeWill',
#  'We Lost #cwc19 in 1st two hours! :(\n#ENGVNZ https://t.co/sGHHGQDDNv',
#  'Great win England. 4 best teams in the semis. Should be good #ENGvsNZ #CWC19',
#  "#ENGvNZ #NZvENG\nPractically, Pakistan is out of the #CWC19 . Big loss to Pakistan, Sarfaraz won't be the future PM. https://t.co/KBCe9yRZ9M",
#  'Pakistan qualification scenarios #CWC19 \n\nScenario 1: Pakistan to score 1800 runs in 50 overs then get Bangladesh o… https://t.co/wckMQXWNtp',
#  'RT @Coral: ENGLAND WIN 🏴\U000e0067\U000e0062\U000e0065\U000e006e\U000e0067\U000e007f\n\nBeat India ✅\nBeat New Zealand ✅\nReach Semi-Finals ✅\n\nTwo wins away from World Cup glory 🏆\n\n#CWC19 https://t…',
#  "RT @cricketworldcup: This is the first time England have qualified for the World Cup semi-finals since '92\n\nThe similarities continue... 😛…",
#  "A glass of #homebrew exotic juice wine &amp; a bbq to celebrate #WeAreEngland qualifying for the #CWC19 semis. It's a v… https://t.co/KGtpOY14lJ",
#  'RT @nvnvenki: Was it the same case in 1992?? 🤣🤣🤣 #fuckpakistan #PKMKB #CWC19 https://t.co/6Zl7Bt7IyI',
#  'RT @englandcricket: #CWC19 semi-finals...\nHere. We. Come 💪\n#ExpressYourself #WeAreEngland #CWC19 https://t.co/XOPV8ubf5g',
#  'RT @ladywithflaws: Safe journey 😂😂😂😂😂😂 #CWC19 #WehaveWewill https://t.co/kFkZrRcVeD',
#  'RT @deeputalks: For Pakistan to qualify:\nBeat Bangladesh by 311 runs after scoring 350\nBeat Bangladesh by 316 runs after scoring 400\nBeat B…',
#  'RT @bbctms: Kane Williamson, NZ captain: \n\n"England got the best of the conditions but they were the better team. They outplayed us in all…',
#  "So how long before Pakistan starts blaming England for winning against NZ just to ruin Pak's qualification chances?… https://t.co/EoJJBrWuU9",
#  'Breaking: A fight has been reported between sarfaraz and malik on alleged peeko wala burqa which sarfaraz had bough… https://t.co/qbqlEmX8NB',
#  'RT @bbctms: Jonny Bairstow: \n\n"We knew these two games were must win. The performances in the last couple of games weren\'t up to scratch. T…',
#  'Believe me this equation is hurting me mOre than anything 💔😭😭😭\nWe still love Pakistan n baCk our team ❤✌ Ub naw sah… https://t.co/1HkSouVNzL',
#  "RT @cricketworldcup: This is the first time England have qualified for the World Cup semi-finals since '92\n\nThe similarities continue... 😛…",
#  'RT @_cleanbowled: Semifinalists\n#CWC19 https://t.co/10OcJsq2rP',
#  "RT @cricketworldcup: This is the first time England have qualified for the World Cup semi-finals since '92\n\nThe similarities continue... 😛…",
#  'RT @sachin_rt: From the dressing room, to the commentary box 🎙️... together always!\n#CWC19 https://t.co/xl66hWTACC',
#  'Pakistanis yet to give up 1992 prophecy 😂😂😂. Chutiye\n#CWC19 #NZvENG #ENGvsNZ https://t.co/3iFAJSPRgk',
#  '@Tabdeeli_Lover SF Qualification Scenario for Pakistan:\n\n- If Pakistan make 350, they need to bowl Bangladesh out f… https://t.co/YCX0j63vIq',
#  'RT @TheViralFever: "Draw me like one of your French girls"\n\n#INDvBAN #CWC19 #IndiaVsBangladesh https://t.co/4Tsngi7acT',
#  'RT @ESPNcricinfo: England beat New Zealand by 119 runs in Durham and seal their spot in the World Cup semi-finals! \n\n#ENGvNZ | #CWC19 | htt…',
#  'RT @mohanstatsman: Assuming New Zealand lose today say by 150 runs. Their NRR will then be 0.085.\nPakistan currently on NRR -0.792 has an i…',
#  '@Atheist_Krishna UPDATED TERMS FOR #PAKISTAN TO QUALIFY: Make 400 runs &amp; dismiss Bangladesh for 84 runs or make 350… https://t.co/hU5VwQSEpx',
#  'All similarities need to be packed down 😂😂😂😂\nNext time :)\n#Pakistan #CWC19 #ENGvNZ https://t.co/yKLXq4FE6j',
#  '@TheRealPCB, 10 INR on Pakistan to qualify.. smile atleast these 10 ₹ will help your economy @waqyounis99 #CWC19 https://t.co/ZPLWZinKsC',
#  'RT @Coral: ENGLAND WIN 🏴\U000e0067\U000e0062\U000e0065\U000e006e\U000e0067\U000e007f\n\nBeat India ✅\nBeat New Zealand ✅\nReach Semi-Finals ✅\n\nTwo wins away from World Cup glory 🏆\n\n#CWC19 https://t…',
#  'RT @deeputalks: If Bangladesh opts to bat first on Friday, Pakistan stand eliminated even before a ball is bowled.\n\n#CWC19 #WeHaveWeWill',
#  'Congratulations @BCCI, @CricketAus, @englandcricket and @BLACKCAPS for their #CWC19 semifinals entry… https://t.co/bvfE3Ycerp',
#  'RT @ShashiTharoor: Themost heartwarming story of #CWC19! https://t.co/LgHzDF9Tkz Well done @anandmahindra @imVkohli @ImRo45 !!',
#  "RT @Saj_PakPassion: The reality is that you shouldn't rely on other teams to help you qualify for the semi-finals. You should control your…",
#  'RT @deeputalks: For Pakistan to qualify:\nBeat Bangladesh by 311 runs after scoring 350\nBeat Bangladesh by 316 runs after scoring 400\nBeat B…',
#  'RT @falamb3: Lesson to be learnt here is that you have to carry your own weight in this World. #CWC19',
#  "RT @mubassir_aman: World Cup will be over in few days. Some of them didn't have a good time but they served their best for years. This is p…",
#  '"پاکستان اب صرف ایک ہی صورت میں سیمی فائنل میں پہنچ سکتا ہے۔ اگر ورلڈ کپ کا تمام ریکارڈ جلا دیا جائے" - شہبازشریف 😂… https://t.co/U31jsX80uS']

# %%
# Show one sample search result by slicing the list...
print(json.dumps(statuses[0], indent=1))
# Out:
# {
#  "created_at": "Wed Jul 03 17:42:33 +0000 2019",
#  "id": 1146474320509755392,
#  "id_str": "1146474320509755392",
#  "text": "RT @SamMorshead_: England will compete in a World Cup semi-final on July 11 for the second time in two years, and this time the oppo won't\u2026",
#  "truncated": false,
#  "entities": {
#   "hashtags": [],
#   "symbols": [],
#   "user_mentions": [
#    {
#     "screen_name": "SamMorshead_",
#     "name": "Sam Morshead",
#     "id": 368955949,
#     "id_str": "368955949",
#     "indices": [
#      3,
#      16
#     ]
#    }
#   ],
#   "urls": []
#  },
#  "metadata": {
#   "iso_language_code": "en",
#   "result_type": "recent"
#  },
#  "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#  "in_reply_to_status_id": null,
#  "in_reply_to_status_id_str": null,
#  "in_reply_to_user_id": null,
#  "in_reply_to_user_id_str": null,
#  "in_reply_to_screen_name": null,
#  "user": {
#   "id": 392155503,
#   "id_str": "392155503",
#   "name": "Cameron",
#   "screen_name": "CamMuxworthy",
#   "location": "Bristol",
#   "description": "BCFC",
#   "url": null,
#   "entities": {
#    "description": {
#     "urls": []
#    }
#   },
#   "protected": false,
#   "followers_count": 253,
#   "friends_count": 348,
#   "listed_count": 2,
#   "created_at": "Sun Oct 16 16:41:00 +0000 2011",
#   "favourites_count": 13970,
#   "utc_offset": null,
#   "time_zone": null,
#   "geo_enabled": true,
#   "verified": false,
#   "statuses_count": 6273,
#   "lang": null,
#   "contributors_enabled": false,
#   "is_translator": false,
#   "is_translation_enabled": false,
#   "profile_background_color": "C0DEED",
#   "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#   "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#   "profile_background_tile": false,
#   "profile_image_url": "http://pbs.twimg.com/profile_images/1140332899373334528/Da8O3UwS_normal.jpg",
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/1140332899373334528/Da8O3UwS_normal.jpg",
#   "profile_banner_url": "https://pbs.twimg.com/profile_banners/392155503/1559248493",
#   "profile_link_color": "0084B4",
#   "profile_sidebar_border_color": "C0DEED",
#   "profile_sidebar_fill_color": "DDEEF6",
#   "profile_text_color": "333333",
#   "profile_use_background_image": true,
#   "has_extended_profile": false,
#   "default_profile": false,
#   "default_profile_image": false,
#   "following": false,
#   "follow_request_sent": false,
#   "notifications": false,
#   "translator_type": "none"
#  },
#  "geo": null,
#  "coordinates": null,
#  "place": null,
#  "contributors": null,
#  "retweeted_status": {
#   "created_at": "Wed Jul 03 17:16:22 +0000 2019",
#   "id": 1146467733577621504,
#   "id_str": "1146467733577621504",
#   "text": "England will compete in a World Cup semi-final on July 11 for the second time in two years, and this time the oppo\u2026 https://t.co/kiSZ802PrB",
#   "truncated": true,
#   "entities": {
#    "hashtags": [],
#    "symbols": [],
#    "user_mentions": [],
#    "urls": [
#     {
#      "url": "https://t.co/kiSZ802PrB",
#      "expanded_url": "https://twitter.com/i/web/status/1146467733577621504",
#      "display_url": "twitter.com/i/web/status/1\u2026",
#      "indices": [
#       116,
#       139
#      ]
#     }
#    ]
#   },
#   "metadata": {
#    "iso_language_code": "en",
#    "result_type": "recent"
#   },
#   "source": "<a href=\"https://about.twitter.com/products/tweetdeck\" rel=\"nofollow\">TweetDeck</a>",
#   "in_reply_to_status_id": null,
#   "in_reply_to_status_id_str": null,
#   "in_reply_to_user_id": null,
#   "in_reply_to_user_id_str": null,
#   "in_reply_to_screen_name": null,
#   "user": {
#    "id": 368955949,
#    "id_str": "368955949",
#    "name": "Sam Morshead",
#    "screen_name": "SamMorshead_",
#    "location": "Commuter belt, London town",
#    "description": "Digital Editor - The Cricketer | Formerly MailOnline, PA and Swindon Advertiser | sam.morshead@thecricketer.com",
#    "url": "https://t.co/TImuH5JX3j",
#    "entities": {
#     "url": {
#      "urls": [
#       {
#        "url": "https://t.co/TImuH5JX3j",
#        "expanded_url": "http://www.thecricketer.com",
#        "display_url": "thecricketer.com",
#        "indices": [
#         0,
#         23
#        ]
#       }
#      ]
#     },
#     "description": {
#      "urls": []
#     }
#    },
#    "protected": false,
#    "followers_count": 7035,
#    "friends_count": 851,
#    "listed_count": 117,
#    "created_at": "Tue Sep 06 14:28:05 +0000 2011",
#    "favourites_count": 1090,
#    "utc_offset": null,
#    "time_zone": null,
#    "geo_enabled": true,
#    "verified": false,
#    "statuses_count": 52817,
#    "lang": null,
#    "contributors_enabled": false,
#    "is_translator": false,
#    "is_translation_enabled": false,
#    "profile_background_color": "C0DEED",
#    "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#    "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#    "profile_background_tile": false,
#    "profile_image_url": "http://pbs.twimg.com/profile_images/1109863583708573696/dCyzB_zu_normal.png",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/1109863583708573696/dCyzB_zu_normal.png",
#    "profile_banner_url": "https://pbs.twimg.com/profile_banners/368955949/1525277881",
#    "profile_link_color": "0084B4",
#    "profile_sidebar_border_color": "000000",
#    "profile_sidebar_fill_color": "000000",
#    "profile_text_color": "000000",
#    "profile_use_background_image": true,
#    "has_extended_profile": true,
#    "default_profile": false,
#    "default_profile_image": false,
#    "following": false,
#    "follow_request_sent": false,
#    "notifications": false,
#    "translator_type": "none"
#   },
#   "geo": null,
#   "coordinates": null,
#   "place": null,
#   "contributors": null,
#   "is_quote_status": false,
#   "retweet_count": 3,
#   "favorite_count": 14,
#   "favorited": false,
#   "retweeted": false,
#   "lang": "en"
#  },
#  "is_quote_status": false,
#  "retweet_count": 3,
#  "favorite_count": 0,
#  "favorited": false,
#  "retweeted": false,
#  "lang": "en"
# }

# %%
# The result of the list comprehension is a list with only one element that
# can be accessed by its index and set to the variable t
t = statuses[0]
#[ status for status in statuses 
#          if status['id'] == 316948241264549888 ][0]

# Explore the variable t to get familiarized with the data structure...

print(t['retweet_count'])
print(t['retweeted'])
# Out:
# 7
# False

# %% [markdown]
# ## Example 6. Extracting text, screen names, and hashtags from tweets

# %%
status_texts = [ status['text'] 
                 for status in statuses ]

screen_names = [ user_mention['screen_name'] 
                 for status in statuses
                     for user_mention in status['entities']['user_mentions'] ]

hashtags = [ hashtag['text'] 
             for status in statuses
                 for hashtag in status['entities']['hashtags'] ]

# Compute a collection of all words from all tweets
words = [ w 
          for t in status_texts 
              for w in t.split() ]

# %%
# Explore the first 5 items for each...

print(json.dumps(status_texts[0:5], indent=1))
print(json.dumps(screen_names[0:5], indent=1)) 
print(json.dumps(hashtags[0:5], indent=1))
print(json.dumps(words[0:5], indent=1))
# Out:
# [
#  "RT @deeputalks: Sixth 50+ score (2 X 100s) for Shakib Al Hasan in #CWC19 - only Sachin Tendulkar has scored more in a single edition of the\u2026",
#  "RT @CensorReports: Dear @ICC and @BCCI  you are hosting one of the best sporting event but we are really not enjoying because of #SanjayMan\u2026",
#  "She is 87 years old but still supporting Indian Cricket Team by shouting. \nThe love for the this beautiful game is\u2026 https://t.co/ycmoGjqP0Q",
#  "RT @ICC: 146 runs to win \ud83d\ude2e \n19 overs remaining \ud83d\ude27 \nSix wickets in hand \ud83d\ude00 \n\nWe have another tense finish on the cards at Edgbaston!\n\n#CWC19 |\u2026",
#  "RT @cricBC: Dhoni's innings these days: \n\nUnable to take singles early in the innings.\n\nRefusing singles late in the innings.\n\n#CWC19"
# ]
# [
#  "deeputalks",
#  "CensorReports",
#  "ICC",
#  "BCCI",
#  "ICC"
# ]
# [
#  "CWC19",
#  "CWC19",
#  "CWC19",
#  "INDvBAN",
#  "MenInGreen"
# ]
# [
#  "RT",
#  "@deeputalks:",
#  "Sixth",
#  "50+",
#  "score"
# ]

# %% [markdown]
# ## Example 7. Creating a basic frequency distribution from the words in tweets

# %%
from collections import Counter

for item in [words, screen_names, hashtags]:
    c = Counter(item)
    print(c.most_common()[:10]) # top 10
    print()
# Out:
# [('RT', 50), ('the', 42), ('#CWC19', 32), ('in', 28), ('a', 22), ('for', 20), ('and', 20), ('to', 20), ('of', 19), ('is', 17)]
#
# [('BCCI', 8), ('cricketworldcup', 8), ('ICC', 5), ('ImRo45', 4), ('cricbuzz', 3), ('Sah75official', 3), ('MRFWorldwide', 2), ('mipaltan', 2), ('gauravkapur', 2), ('rameshlaus', 2)]
#
# [('CWC19', 37), ('INDvBAN', 17), ('BANvIND', 10), ('TeamIndia', 8), ('RiseOfTheTigers', 4), ('Dhoni', 4), ('Pandya', 2), ('Bangladesh', 2), ('RohitSharma', 2), ('cwc19', 2)]

# %% [markdown]
# ## Example 8. Create a prettyprint function to display tuples in a nice tabular format

# %%
def prettyprint_counts(label, list_of_tuples):
    print("\n{:^20} | {:^6}".format(label, "Count"))
    print("*"*40)
    for k,v in list_of_tuples:
        print("{:20} | {:>6}".format(k,v))

# %%
for label, data in (('Word', words), 
                    ('Screen Name', screen_names), 
                    ('Hashtag', hashtags)):
    
    c = Counter(data)
    prettyprint_counts(label, c.most_common()[:10])
# Out:
#         Word         | Count
# ****************************************
# RT                   |     50
# the                  |     42
# #CWC19               |     32
# in                   |     28
# a                    |     22
# for                  |     20
# and                  |     20
# to                   |     20
# of                   |     19
# is                   |     17
#
#     Screen Name      | Count
# ****************************************
# BCCI                 |      8
# cricketworldcup      |      8
# ICC                  |      5
# ImRo45               |      4
# cricbuzz             |      3
# Sah75official        |      3
# MRFWorldwide         |      2
# mipaltan             |      2
# gauravkapur          |      2
# rameshlaus           |      2
#
#       Hashtag        | Count
# ****************************************
# CWC19                |     37
# INDvBAN              |     17
# BANvIND              |     10
# TeamIndia            |      8
# RiseOfTheTigers      |      4
# Dhoni                |      4
# Pandya               |      2
# Bangladesh           |      2
# RohitSharma          |      2
# cwc19                |      2

# %% [markdown]
# ## Example 9. Finding the most popular retweets

# %%
retweets = [
            # Store out a tuple of these three values ...
            (status['retweet_count'], 
             status['retweeted_status']['user']['screen_name'],
             status['text'].replace("\n","\\")) 
            
            # ... for each status ...
            for status in statuses 
            
            # ... so long as the status meets this condition.
                if 'retweeted_status' in status
           ]

# %% [markdown]
# We can build another `prettyprint` function to print entire tweets with their retweet count.
#
# We also want to split the text of the tweet in up to 3 lines, if needed.

# %%
row_template = "{:^7} | {:^15} | {:50}"
def prettyprint_tweets(list_of_tuples):
    print()
    print(row_template.format("Count", "Screen Name", "Text"))
    print("*"*60)
    for count, screen_name, text in list_of_tuples:
        print(row_template.format(count, screen_name, text[:50]))
        if len(text) > 50:
            print(row_template.format("", "", text[50:100]))
            if len(text) > 100:
                print(row_template.format("", "", text[100:]))

# %%
# Slice off the first 5 from the sorted results and display each item in the tuple

prettyprint_tweets(sorted(retweets, reverse=True)[:10])
# Out:
#  Count  |   Screen Name   | Text
# ************************************************************
#  3565   |      BCCI       | RT @BCCI: 💯 Rohit Sharma, you genius. \\Back to ba
#         |                 | ck centuries for @ImRo45 and fourth in #CWC19, 26t
#         |                 | h overall in ODIs 👏👏👏👏 https://t.co/ADD…
#  1103   |       ICC       | RT @ICC: Century for Rohit Sharma!\\He becomes jus
#         |                 | t the second player to score four hundreds in a si
#         |                 | ngle World Cup campaign. \\What a tourn…
#   806   |   gauravkapur   | RT @gauravkapur: I don’t know about the Man of the
#         |                 |  Match, but we have an undisputed winner of the Fa
#         |                 | n of the Match 🙌💖 #CWC19 https://t.co/D…
#   679   |    mipaltan     | RT @mipaltan: ODI averages as an Opener:\\🇮🇳 Rohit
#         |                 |  Sharma - 57.88\🇿🇦 Hashim Amla - 49.89\🇮🇳 Sachin T
#         |                 | endulkar - 48.29\\#OneFamily #CricketMe…
#   569   |   rameshlaus    | RT @rameshlaus: If #Dhoni hits singles in death ov
#         |                 | ers, he is wrong..\\If #Dhoni retains strike, so h
#         |                 | e can hit boundaries and doesn't take s…
#   562   |      BCCI       | RT @BCCI: Vice-captain @ImRo45 is our key performe
#         |                 | r post #TeamIndia's innings 😎👌🏻  #BANvIND #CWC19 h
#         |                 | ttps://t.co/SOo5S7Wr7s
#   523   | cricketworldcup | RT @cricketworldcup: 122*\57\140\1\18\102\\100* to
#         |                 | day, and he's still going. \\Rohit Sharma's #CWC19
#         |                 |  campaign just gets better and better.…
#   446   |   gauravkapur   | RT @gauravkapur: Most centuries by an Indian batsm
#         |                 | an in a single World Cup: Rohit Sharma, 4 ... and
#         |                 | counting 🚀 #Hitman #CWC19 🇮🇳 https://t.…
#   321   |   rameshlaus    | RT @rameshlaus: #Dhoni - 35 runs from 33 Balls.. 4
#         |                 |  Fours.. 106 SR.. \\Good value addition in the dea
#         |                 | th overs.. \\#INDvBAN #CWC19
#   280   |   Cricprabhu    | RT @Cricprabhu: Dear @StarSportsIndia. You are los
#         |                 | ing it. Someone has to tell @sanjaymanjrekar he ha
#         |                 | s to use his cricketing brains &amp; game k…
